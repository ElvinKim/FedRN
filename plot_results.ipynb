# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. MNIST

# %% [markdown]
# ### 1.1 IID

# %%
result_dir = "./save/mnist/"

dataset = 'mnist'
model = 'cnn'
epochs = 50
frac = 0.1
iid = True
lr = 0.01
momentum = 0.5

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 51)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc))

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 51)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc))

# PairFlip Noise
pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                   model, 
                                                                                   epochs, 
                                                                                   frac, 
                                                                                   iid,
                                                                                   lr,
                                                                                   momentum,
                                                                                   'pairflip',
                                                                                   '0.45')
pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

x = range(1, 51)
plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(0.45))
print('PairFlip({})'.format(0.45), max(pf_noise_acc))


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 98.5199966430664
# Sym(0.2) 97.31999969482422
# Sym(0.5) 96.45999908447266
# PairFlip(0.45) 75.58999633789062

# %% [markdown]
# ### 1.2 Non-IID

# %%
result_dir = "./save/mnist/"

dataset = 'mnist'
model = 'cnn'
epochs = 50
frac = 0.1
iid = False
lr = 0.01
momentum = 0.5
noise_type = 'symmetric'

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 51)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc))

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 51)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc))

# PairFlip Noise
pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                   model, 
                                                                                   epochs, 
                                                                                   frac, 
                                                                                   iid,
                                                                                   lr,
                                                                                   momentum,
                                                                                   'pairflip',
                                                                                   '0.45')
pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

x = range(1, 51)
plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(0.45))
print('PairFlip({})'.format(0.45), max(pf_noise_acc))


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 95.98999786376952
# Sym(0.2) 80.30999755859375
# Sym(0.5) 79.70999908447266
# PairFlip(0.45) 64.73999786376953

# %% [markdown]
# ## 2. CIFAR 10

# %% [markdown]
# ### 2.1 IID

# %%
result_dir = "./save/cifar10/"

dataset = 'cifar'
model = 'cnn'
epochs = 100
frac = 0.1
iid = True
lr = 0.01
momentum = 0.5
noise_type = 'symmetric'

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 101)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc))

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc))

# PairFlip Noise
pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                   model, 
                                                                                   epochs, 
                                                                                   frac, 
                                                                                   iid,
                                                                                   lr,
                                                                                   momentum,
                                                                                   'pairflip',
                                                                                   '0.45')
pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

x = range(1, 101)
plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(0.45))
print('PairFlip({})'.format(0.45), max(pf_noise_acc))


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 54.20000076293945
# Sym(0.2) 45.79999923706055
# Sym(0.5) 39.27999877929688
# PairFlip(0.45) 33.779998779296875

# %% [markdown]
# ### 2.2 Non-IID

# %%
result_dir = "./save/cifar10/"

dataset = 'cifar'
model = 'cnn'
epochs = 100
frac = 0.1
iid = False
lr = 0.01
momentum = 0.5
noise_type = 'symmetric'

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 101)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc))

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc))

# PairFlip Noise
pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                   model, 
                                                                                   epochs, 
                                                                                   frac, 
                                                                                   iid,
                                                                                   lr,
                                                                                   momentum,
                                                                                   'pairflip',
                                                                                   '0.45')
pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

x = range(1, 101)
plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(0.45))
print('PairFlip({})'.format(0.45), max(pf_noise_acc))


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 47.15999984741211
# Sym(0.2) 35.70000076293945
# Sym(0.5) 27.739999771118164
# PairFlip(0.45) 25.01000022888184
