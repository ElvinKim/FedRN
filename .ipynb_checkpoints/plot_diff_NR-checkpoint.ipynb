# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. MNIST

# %% [markdown]
# ### 1.1 IID

# %%
result_dir = "./save/mnist/"

dataset = 'mnist'
model = 'cnn'
epochs = 50
frac = 0.1
iid = True
lr = 0.01
momentum = 0.5

# %%
no_noise_acc[40:].mean()
# Out:
# 98.4279998779297

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 51)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc), no_noise_acc[40:].mean())

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 51)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc), sym_noise_acc[40:].mean())

for noise_rate in [0.45]:
    # PairFlip Noise
    pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       'pairflip',
                                                                                       noise_rate)
    pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

    x = range(1, 51)
    plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(noise_rate))
    print('PairFlip({})'.format(noise_rate), max(pf_noise_acc), pf_noise_acc[40:].mean())


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 98.5199966430664 98.4279998779297
# Sym(0.2) 97.31999969482422 96.7609992980957
# Sym(0.5) 96.45999908447266 95.91799926757812
# PairFlip(0.45) 75.58999633789062 64.81400032043457

# %% [markdown]
# ### 1.2 Non-IID

# %%
result_dir = "./save/mnist/"

dataset = 'mnist'
model = 'cnn'
epochs = 50
frac = 0.1
iid = False
lr = 0.01
momentum = 0.5
noise_type = 'symmetric'

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 51)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc))

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 51)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc))

# PairFlip Noise
pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                   model, 
                                                                                   epochs, 
                                                                                   frac, 
                                                                                   iid,
                                                                                   lr,
                                                                                   momentum,
                                                                                   'pairflip',
                                                                                   '0.45')
pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

x = range(1, 51)
plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(0.45))
print('PairFlip({})'.format(0.45), max(pf_noise_acc))


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 95.98999786376952
# Sym(0.2) 80.30999755859375
# Sym(0.5) 79.70999908447266
# PairFlip(0.45) 64.73999786376953

# %% [markdown]
# ## 2. CIFAR 10

# %% [markdown]
# ### 2.1 IID

# %%
result_dir = "./save/cifar10/"

dataset = 'cifar'
model = 'cnn'
epochs = 100
frac = 0.1
iid = True
lr = 0.01
momentum = 0.5
noise_type = 'symmetric'

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 101)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc), no_noise_acc[90:].mean())

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc), sym_noise_acc[90:].mean())


for noise_rate in [0.25, 0.45]:
    # PairFlip Noise
    pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       'pairflip',
                                                                                       noise_rate)
    

    pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(noise_rate))
    print('PairFlip({})'.format(noise_rate), max(pf_noise_acc), pf_noise_acc[90:].mean())


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 54.20000076293945 53.897999954223636
# Sym(0.2) 45.79999923706055 42.01499977111816
# Sym(0.5) 39.27999877929688 26.148000144958495
# PairFlip(0.25) 43.36999893188477 41.12999992370605
# PairFlip(0.45) 33.779998779296875 30.729999923706053

# %% [markdown]
# ### 2.2 Non-IID

# %%
result_dir = "./save/cifar10/"

dataset = 'cifar'
model = 'cnn'
epochs = 100
frac = 0.1
iid = False
lr = 0.01
momentum = 0.5
noise_type = 'symmetric'

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 101)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc), no_noise_acc[90:].mean())

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       noise_type,
                                                                                       noise_rate)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc), sym_noise_acc[90:].mean())

    # PairFlip Noise
for noise_rate in [0.25, 0.45]:
    pairflip_f = 'fedLNL_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}].csv'.format(dataset, 
                                                                                       model, 
                                                                                       epochs, 
                                                                                       frac, 
                                                                                       iid,
                                                                                       lr,
                                                                                       momentum,
                                                                                       'pairflip',
                                                                                       noise_rate)
    pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(noise_rate))
    print('PairFlip({})'.format(noise_rate), max(pf_noise_acc), pf_noise_acc[90:].mean())


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 47.15999984741211 43.542000198364256
# Sym(0.2) 35.70000076293945 25.001999855041504
# Sym(0.5) 27.739999771118164 16.060000133514404
# PairFlip(0.25) 29.8799991607666 25.717999839782713
# PairFlip(0.45) 25.01000022888184 20.65699996948242

# %% [markdown]
# ### 2.3 IID (Joint Optimization)

# %%
result_dir = "./save/cifar10/"

dataset = 'cifar'
model = 'cnn'
epochs = 100
frac = 0.1
iid = True
lr = 0.01
momentum = 0.5

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 101)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc), no_noise_acc[90:].mean())

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_JointOpt_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}]_BEGIN[{}]_ALPHA[{}]_BETA[{}].csv'.format(dataset, 
                                                                                                                          model, 
                                                                                                                          epochs, 
                                                                                                                          frac, 
                                                                                                                          iid,
                                                                                                                          lr,
                                                                                                                          momentum,
                                                                                                                          noise_type,
                                                                                                                          noise_rate, 
                                                                                                                          20,
                                                                                                                          1.2,
                                                                                                                          0.8)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc), sym_noise_acc[90:].mean())

# PairFlip Noise

for noise_rate in [0.25, 0.45]:
    pairflip_f = 'fedLNL_JointOpt_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}]_BEGIN[{}]_ALPHA[{}]_BETA[{}].csv'.format(dataset, 
                                                                                                                          model, 
                                                                                                                          epochs, 
                                                                                                                          frac, 
                                                                                                                          iid,
                                                                                                                          lr,
                                                                                                                          momentum,
                                                                                                                          'pairflip',
                                                                                                                          noise_rate, 
                                                                                                                          20,
                                                                                                                          1.2,
                                                                                                                          0.8)

    pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(noise_rate))
    print('PairFlip({})'.format(noise_rate), max(pf_noise_acc), pf_noise_acc[90:].mean())


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 54.20000076293945 53.897999954223636
# Sym(0.2) 45.6500015258789 42.53299980163574
# Sym(0.5) 38.81999969482422 37.1939998626709
# PairFlip(0.25) 44.91999816894531 42.1689998626709
# PairFlip(0.45) 38.58000183105469 37.43499984741211

# %% [markdown]
# ### 2.4 Non-IID (Joint Optimization)

# %%
result_dir = "./save/cifar10/"

dataset = 'cifar'
model = 'cnn'
epochs = 100
frac = 0.1
iid = False
lr = 0.01
momentum = 0.5

# %%
# No Noise
no_noise_f = 'fed_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}].csv'.format(dataset, 
                                                                  model, 
                                                                  epochs, 
                                                                  frac, 
                                                                  iid,
                                                                  lr,
                                                                  momentum)

no_noise_acc = pd.read_csv(result_dir + no_noise_f)['test_acc']

x = range(1, 101)
plt.plot(x, no_noise_acc, label='No Noise')

print('No Noise', max(no_noise_acc), no_noise_acc[90:].mean())

# Symmetric Noise
for noise_rate in [0.2, 0.5]:
    sym_f = 'fedLNL_JointOpt_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}]_BEGIN[{}]_ALPHA[{}]_BETA[{}].csv'.format(dataset, 
                                                                                                                          model, 
                                                                                                                          epochs, 
                                                                                                                          frac, 
                                                                                                                          iid,
                                                                                                                          lr,
                                                                                                                          momentum,
                                                                                                                          noise_type,
                                                                                                                          noise_rate, 
                                                                                                                          20,
                                                                                                                          1.2,
                                                                                                                          0.8)
    sym_noise_acc = pd.read_csv(result_dir + sym_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, sym_noise_acc, label='Sym({})'.format(noise_rate))

    print('Sym({})'.format(noise_rate), max(sym_noise_acc), sym_noise_acc[90:].mean())

# PairFlip Noise

for noise_rate in [0.25, 0.45]:
    pairflip_f = 'fedLNL_JointOpt_{}_{}_{}_C[{}]_IID[{}]_LR[{}]_MMT[{}]_NT[{}]_NR[{}]_BEGIN[{}]_ALPHA[{}]_BETA[{}].csv'.format(dataset, 
                                                                                                                          model, 
                                                                                                                          epochs, 
                                                                                                                          frac, 
                                                                                                                          iid,
                                                                                                                          lr,
                                                                                                                          momentum,
                                                                                                                          'pairflip',
                                                                                                                          noise_rate, 
                                                                                                                          20,
                                                                                                                          1.2,
                                                                                                                          0.8)

    pf_noise_acc = pd.read_csv(result_dir + pairflip_f)['test_acc']

    x = range(1, 101)
    plt.plot(x, pf_noise_acc, label='PairFlip({})'.format(noise_rate))
    print('PairFlip({})'.format(noise_rate), max(pf_noise_acc), pf_noise_acc[90:].mean())


plt.legend()
plt.show()
plt.close()
# Out:
# No Noise 54.20000076293945 53.897999954223636
# Sym(0.2) 45.6500015258789 42.53299980163574
# Sym(0.5) 38.81999969482422 37.1939998626709
# PairFlip(0.25) 44.91999816894531 42.1689998626709
# PairFlip(0.45) 38.58000183105469 37.43499984741211

# %%
import numpy as np

# %%
np.random.choice(range(10), p=[0.1 for i in range(10)])
# Out:
# 3

# %%
noise_rate = 0.2
true_label = 3
a = [noise_rate / 9] * 10
a[3] = 1 - noise_rate

# %%
def noisify_label(true_label, noise_rate, num_classes=10):
    a = [noise_rate / (num_classes - 1)] * num_classes
    a[true_label] = 1 - noise_rate
    return np.random.choice(range(num_classes), p=a)
